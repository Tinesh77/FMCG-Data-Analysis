# %% [markdown]
# # DownLoad the Latest Version of the Dataset(FMCG Data)

# %%
path = kagglehub.dataset_download("debashis74017/nifty-fmcg-data-1-minute-5-minute-daily-data") 
print("Path to dataset files:", path)
